# %%
import xlrd
import xlwt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import random
import time

wb = xlrd.open_workbook(r"C:\Users\User\Desktop\Диплом мага\Книга1.xlsx")
sheet = wb.sheet_by_index(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-11b23fa649d3> in <module>
#       1 import xlrd
# ----> 2 import xlwt
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#       5 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'xlwt'

# %%
temperature = []
pressure = []
t = 700
i = 0
for i in range (0, t):
    temperature.append(sheet.cell_value(i, 2))
    pressure.append(sheet.cell_value(i, 0))
    
plt.plot(temperature)
plt.show()
plt.plot(pressure)
plt.show()

# %%
d=42
h=5
rf = (d-h)/h
print(rf)
# Out:
# 7.4

# %%
res_start = 408700
res_sum = []
for i in range(0, t):
    res_sum.append(10**(540/(temperature[i]+200)*(20+np.log10(res_start))-20)/3.5)
plt.plot(res_sum)
plt.show()
res_temp = np.median(res_sum)
print(res_temp)
# Out:
# 256455.68729769794

# %%
pres_start = 14*10.197
res_sum_pres = []
for i in range(0, t):
    res_sum_pres.append(res_sum[i]*pressure[i]/pres_start)
res_pres = np.median(res_sum_pres)

plt.plot(res_sum_pres)
plt.show()

print(res_pres)
# Out:
# 242939.6795957102
